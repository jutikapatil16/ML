# %% [markdown]
# # DATATYPES AND ATTRIBUTES

# %%
import numpy as np

# %%
a1 = np.array([1,2,3])
a1
# Out:
# array([1, 2, 3])

# %%
a2 = np.array([[1,4,6],[4,8,9]])
a2
# Out:
# array([[1, 4, 6],
#        [4, 8, 9]])

# %%
a3 = np.array([[1,4,6],[4,8,9],[7,8,9]])
a3
# Out:
# array([[1, 4, 6],
#        [4, 8, 9],
#        [7, 8, 9]])

# %%
a4= np.array([[[1,4,6],[4,8,9],[7,8,9]],
             [[3,1,8],[5,8,9],[5,3,2]]])
a4
# Out:
# array([[[1, 4, 6],
#         [4, 8, 9],
#         [7, 8, 9]],
#
#        [[3, 1, 8],
#         [5, 8, 9],
#         [5, 3, 2]]])

# %%
a3.dtype
# Out:
# dtype('int32')

# %%
 a1.dtype
# Out:
# dtype('int32')

# %%
a2.dtype
# Out:
# dtype('int32')

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a3.shape
# Out:
# (3, 3)

# %%
a4.shape
# Out:
# (2, 3, 3)

# %%
a3.size
# Out:
# 9

# %%
a4.size
# Out:
# 18

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
import pandas as pd

df = pd.DataFrame(a2)
df
# Out:
#    0  1  2
# 0  1  4  6
# 1  4  8  9

# %% [markdown]
# # CREATING NUMPY ARRAYS

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
ra = np.random.randint(0,10,(2,3))
ra
# Out:
# array([[0, 1, 7],
#        [3, 1, 0]])

# %%
ra = np.random.randint(0,10)
ra
# Out:
# 8

# %%
np.random.seed(99)
ra1 =np.random.randit((3,4))
ra1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2720/3149893531.py in <module>
#       1 np.random.seed(99)
# ----> 2 ra1 =np.random.randit((3,4))
#       3 ra1
#
# AttributeError: module 'numpy.random' has no attribute 'randit'

# %%
a3

# %%
a3[:2,:2]

# %%
a4[:2,:4,:2]

# %%
a5 = np.random.randint(10,size=(2,4,3,6))
a5
# (set ,in 1 set , row, column, )

# %%
a3*a3
# Out:
# array([[ 1, 16, 36],
#        [16, 64, 81],
#        [49, 64, 81]])

# %%
a2*a3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2720/1739192805.py in <module>
# ----> 1 a2*a3
#
# ValueError: operands could not be broadcast together with shapes (2,3) (3,3)

# %%
# a2**2
np.exp(a1)
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
np.square(a2) 
# both will give same
# Out:
# array([[ 1, 16, 36],
#        [16, 64, 81]], dtype=int32)

# %%
a2/a2
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
a2//a2
# Out:
# array([[1, 1, 1],
#        [1, 1, 1]], dtype=int32)

# %%
a2%a2
# Out:
# array([[0, 0, 0],
#        [0, 0, 0]], dtype=int32)

# %% [markdown]
# # AGGREGATION

# %% [markdown]
# performing same operation on a multiple things

# %%
sum (a2) #sum of all eements of a column in one row

# np.mean(a2)
# np.std(a2)
# np.sqrt(np.var(a2))
# Out:
# array([ 5, 12, 15])

# %%
np.sum(a2)
# sum of all the elements
# Out:
# 32

# %%
np.max(a2)
# Out:
# 9

# %%
a2
# Out:
# array([[1, 4, 6],
#        [4, 8, 9]])

# %%
np.mean(a2)
# Out:
# 5.333333333333333

# %%
# variance = the measure of average degree to which eahc number is different from the other numbers

# %% [markdown]
# # Reshaping and tranposing

# %%
# when can reshape the array to multiply it with other array

# %%
a2_reshape =a2.reshape(2,3,1)
a2_reshape
# (number , row , column)
# Out:
# array([[[1],
#         [4],
#         [6]],
#
#        [[4],
#         [8],
#         [9]]])

# %%
a2_reshape*a3
# (2,1,3)(3,3)
# both should be equal
# OR
# one of them should be one
# (2,3,1)(3,3)
# Out:
# array([[[ 1,  4,  6],
#         [16, 32, 36],
#         [42, 48, 54]],
#
#        [[ 4, 16, 24],
#         [32, 64, 72],
#         [63, 72, 81]]])

# %%
a2.T
# Out:
# array([[1, 4],
#        [4, 8],
#        [6, 9]])

# %%
a2
# Out:
# array([[1, 4, 6],
#        [4, 8, 9]])

# %%
np.random.seed(0)

mat1 = np.random.randint(10,size=(2,3))
mat2 = np.random.randint(10 , size= (2,2))
mat1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
mat2
# Out:
# array([[3, 5, 2],
#        [4, 7, 6],
#        [8, 8, 1],
#        [6, 7, 7],
#        [8, 1, 5]])

# %%
np.dot(mat1,mat2.T)
# dot product will give 2*5 when 2*3 and 5*3
# Out:
# array([[ 21,  38,  43,  51,  55],
#        [ 62, 115,  89, 130,  76]])

# %%
mat1*mat2
# element wise will give error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2720/2107253770.py in <module>
# ----> 1 mat1*mat2
#       2 # element wise will give 3*3 when both were 2*3
#
# ValueError: operands could not be broadcast together with shapes (2,3) (5,3)

# %%
mat3 = np.random.randint(10,size=(2,3))
mat3*mat1 
# both 2*3
# Out:
# array([[15,  0,  0],
#        [ 6, 21, 72]])

# %% [markdown]
# # Comparison Operators

# %%
a1
# Out:
# array([1, 2, 3])

# %%
a2
# Out:
# array([[1, 4, 6],
#        [4, 8, 9]])

# %%
a2 >mat2

# why???????????
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2720/811283304.py in <module>
# ----> 1 a2 >mat2
#       2
#       3 # why???????????
#
# ValueError: operands could not be broadcast together with shapes (2,3) (5,3)

# %%
np.sort(mat2)
# Out:
# array([[2, 3, 5],
#        [4, 6, 7],
#        [1, 8, 8],
#        [6, 7, 7],
#        [1, 5, 8]])
